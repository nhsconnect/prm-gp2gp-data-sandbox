# %% [markdown]
# # ASID Lookup Investigation

# %% [markdown]
# We use the ASID lookup file, emailed to us on the 1st of every month from the DIR team. This is used in the ODS Downloader along with the ODS Portal API call to produce the organistion metadata JSON file. A list of organisations are obtained from ODS Portal API call, and then enriched with ASIDs using the ASID lookup file. The organistion metadata JSON file is then used as an input for the data pipeline.
#
# This investigation is to see what the differences are between earlier ASID Lookup files and latter ASID Lookup files

# %%
import pandas as pd

# %%
asid_file_location = "s3://prm-gp2gp-data-sandbox-dev/asid-lookup/"
asid_one = pd.read_csv(asid_file_location + "asidLookup-Nov-2020.csv.gz")
asid_two = pd.read_csv(asid_file_location + "asidLookup-Apr-2021.csv.gz")

# %%
asid_one = asid_one.loc[asid_one["OrgType"] == "GP Practice"].drop("PName", axis=1)
asid_two = asid_two.loc[asid_two["OrgType"] == "GP Practice"].drop("PName", axis=1)

# %%
asid_one.shape[0]
# Out:
# 14372

# %%
asid_two.shape[0]
# Out:
# 14424

# %%
len(set(asid_one["ASID"].values).intersection(set(asid_two["ASID"].values)))
# Out:
# 14236

# %% [markdown]
# Finding one is not the subset of the other

# %%
unique_asid_rows = pd.concat([asid_one, asid_two]).drop_duplicates()

# %%
unique_asid_rows["ASID"].value_counts().value_counts()
# Out:
# 1    14439
# 2      121
# Name: ASID, dtype: int64

# %%
unique_asid_counts = unique_asid_rows["ASID"].value_counts()
unique_asid_rows_over_one_bool = unique_asid_counts > 1
repeated_asids = unique_asid_counts.loc[unique_asid_rows_over_one_bool].index

# %%
asid_two.set_index("ASID").loc[repeated_asids]
# Out:
#                 NACS                        OrgName  \
# 200000016875  B84007              BRIG ROYD SURGERY
# 200000018990  B83611        BARKEREND HC - EL ELIWI
# 200000021139  Y00446               MAGHULL PRACTICE
# 200000023662  L84052    SEVERNSIDE MEDICAL PRACTICE
# 762405575015  J81076        THE TOLLERFORD PRACTICE
# ...              ...                            ...
# 931662763040  P87022  MOCHA PARADE MEDICAL PRACTICE
# 200000017694  D81629            WILLOW TREE SURGERY
# 200000023104  H84059     THAMESIDE MEDICAL PRACTICE
# 579228803014  E85750  SPRING GROVE MEDICAL PRACTICE
# 200000023563  L84052    SEVERNSIDE MEDICAL PRACTICE
#
#                                                      MName      OrgType  \
# 200000016875                       THE PHOENIX PARTNERSHIP  GP Practice
# 200000018990                       THE PHOENIX PARTNERSHIP  GP Practice
# 200000021139  EGTON MEDICAL INFORMATION SYSTEMS LTD (EMIS)  GP Practice
# 200000023662                       THE PHOENIX PARTNERSHIP  GP Practice
# 762405575015                       THE PHOENIX PARTNERSHIP  GP Practice
# ...                                                    ...          ...
# 931662763040                       IN PRACTICE SYSTEMS LTD  GP Practice
# 200000017694                       THE PHOENIX PARTNERSHIP  GP Practice
# 200000023104  EGTON MEDICAL INFORMATION SYSTEMS LTD (EMIS)  GP Practice
# 579228803014  EGTON MEDICAL INFORMATION SYSTEMS LTD (EMIS)  GP Practice
# 200000023563                       THE PHOENIX PARTNERSHIP  GP Practice
#
#               PostCode
# 200000016875   HX6 4BN
# 200000018990   BD3 0BS
# 200000021139   L31 0DJ
# 200000023662   GL1 1XR
# 762405575015   DT6 5BN
# ...                ...
# 931662763040    M7 3SE
# 200000017694   PE2 5RQ
# 200000023104  TW11 8HU
# 579228803014   TW7 4HG
# 200000023563   GL1 1XR
#
# [121 rows x 5 columns]

# %%
asid_one.set_index("ASID").loc[repeated_asids]
# Out:
#                 NACS                        OrgName  \
# 200000016875  B84007     DR LJ PICKLES AND PARTNERS
# 200000018990  B83611        BARKEREND HC - EL ELIWI
# 200000021139  Y00446                MAGHULL SURGERY
# 200000023662  L84052  GLOUCESTER CITY HEALTH CENTRE
# 762405575015  J81076        THE TOLLERFORD PRACTICE
# ...              ...                            ...
# 931662763040  P87022  MOCHA PARADE MEDICAL PRACTICE
# 200000017694  D81629        THE WILLOW TREE SURGERY
# 200000023104  H84059             CHILDS (THAMESIDE)
# 579228803014  E85750  SPRING GROVE MEDICAL PRACTICE
# 200000023563  L84052  GLOUCESTER CITY HEALTH CENTRE
#
#                                                      MName      OrgType  \
# 200000016875                       THE PHOENIX PARTNERSHIP  GP Practice
# 200000018990                       THE PHOENIX PARTNERSHIP  GP Practice
# 200000021139  EGTON MEDICAL INFORMATION SYSTEMS LTD (EMIS)  GP Practice
# 200000023662                       THE PHOENIX PARTNERSHIP  GP Practice
# 762405575015                       THE PHOENIX PARTNERSHIP  GP Practice
# ...                                                    ...          ...
# 931662763040                       IN PRACTICE SYSTEMS LTD  GP Practice
# 200000017694                       THE PHOENIX PARTNERSHIP  GP Practice
# 200000023104  EGTON MEDICAL INFORMATION SYSTEMS LTD (EMIS)  GP Practice
# 579228803014  EGTON MEDICAL INFORMATION SYSTEMS LTD (EMIS)  GP Practice
# 200000023563                       THE PHOENIX PARTNERSHIP  GP Practice
#
#               PostCode
# 200000016875   HX6 4BN
# 200000018990   BD3 8QH
# 200000021139   L31 0DJ
# 200000023662   GL1 1XR
# 762405575015   DT2 0DB
# ...                ...
# 931662763040    M7 1QE
# 200000017694   PE2 5RQ
# 200000023104  TW11 8HU
# 579228803014   TW7 4HQ
# 200000023563   GL1 1XR
#
# [121 rows x 5 columns]

# %% [markdown]
# ## Outcome
# - Produce an ASID lookup file that contains the most recent entry for all ASIDs

# %%
# Import ASID look up files
asid_file_location = "s3://prm-gp2gp-data-sandbox-dev/asid-lookup/"
asid_files = [
    "asidLookup-Nov-2020.csv.gz",
    "asidLookup-Dec-2020.csv.gz",
    "asidLookup-Jan-2021.csv.gz",
    "asidLookup-Feb-2021.csv.gz",
    "asidLookup-Mar-2021.csv.gz",
    "asidLookup-Apr-2021.csv.gz",
    
]
asid_lookup_files = [asid_file_location + f for f in asid_files]
asid_lookup = pd.concat((
    pd.read_csv(f)
    for f in asid_lookup_files
))
asid_lookup = asid_lookup.drop_duplicates().groupby("ASID").last().reset_index()

# %%
asid_lookup
# Out:
#                ASID    NACS  \
# 0      000032357014  K82022
# 1      000083218040   FQG85
# 2      000166272047  A83031
# 3      000226234045   FDC52
# 4      000327466041   FXX85
# ...             ...     ...
# 38492  999707455039   FK696
# 38493  999756796044  P91627
# 38494  999757880037   FJL19
# 38495  999785485049   FWC78
# 38496   YEA-0000806     YEE
#
#                                                  OrgName  \
# 0                                      KINGSWOOD SURGERY
# 1                                   THE WILLOWS PHARMACY
# 2                                CARMEL MEDICAL PRACTICE
# 3                                     DAY LEWIS PHARMACY
# 4                                    PRESCRIPTIONS FIRST
# ...                                                  ...
# 38492                                     LLOYDSPHARMACY
# 38493                             LOSTOCK MEDICAL CENTRE
# 38494                                     LLOYDSPHARMACY
# 38495                                     DUKES PHARMACY
# 38496  NATIONAL CARE RECORDS SERVICE SPINE (TEST HARN...
#
#                                               MName              PName  \
# 0      EGTON MEDICAL INFORMATION SYSTEMS LTD (EMIS)           EMIS Web
# 1                               AAH PHARMACEUTICALS     ProScript Link
# 2                           THE PHOENIX PARTNERSHIP           SystmOne
# 3                                        RX SYSTEMS  ProScript Connect
# 4                                        RX SYSTEMS  ProScript Connect
# ...                                             ...                ...
# 38492                           LLOYDS PHARMACY LTD            CoMPaSS
# 38493  EGTON MEDICAL INFORMATION SYSTEMS LTD (EMIS)           EMIS Web
# 38494                           LLOYDS PHARMACY LTD            CoMPaSS
# 38495                                  HELIX HEALTH          PharmaSys
# 38496                                          None               None
#
#                       OrgType  PostCode
# 0                 GP Practice  HP13 7UN
# 1                    Pharmacy  BN27 4LE
# 2                 GP Practice   DL3 8SQ
# 3                    Pharmacy  SP10 1HF
# 4                    Pharmacy   PR8 6QL
# ...                       ...       ...
# 38492                Pharmacy   S11 8HN
# 38493             GP Practice   M32 9PA
# 38494                Pharmacy   FY5 5HT
# 38495                Pharmacy  RG45 6DS
# 38496  Local Service Provider  EC1A 7AJ
#
# [38497 rows x 7 columns]
